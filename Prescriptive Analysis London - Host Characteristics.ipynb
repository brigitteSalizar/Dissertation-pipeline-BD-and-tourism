# %% [markdown]
# # 1. Problem statement
#
# 1. To what extent can structured Airbnb data support decision-making frameworks for tourism planning?
# 2. What analytical frameworks are most suitable for leveraging Airbnb Big Data in strategic tourism planning?
# 3. How can structured data from Airbnb listings inform the adaptation of prescriptive models for demand forecasting and host behavior analysis in tourism destinations?
# 4. Can forecasting models built on Airbnb data from one city be applied effectively to other cities for strategic tourism planning?

# %% [markdown]
# # 2. Data Collection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
pd.set_option("display.max_columns", None)

# %%
df_1 = pd.read_csv("/Users/brigitte/Desktop/Tesis Maestria/Thesis pipeline OG/LONDON/listings.csv", encoding="utf-8")

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96651 entries, 0 to 96650
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              96651 non-null  int64
#  1   name                            96651 non-null  object
#  2   host_id                         96651 non-null  int64
#  3   host_name                       96611 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   96651 non-null  object
#  6   latitude                        96651 non-null  float64
#  7   longitude                       96651 non-null  float64
#  8   room_type                       96651 non-null  object
#  9   price                           62684 non-null  float64
#  10  minimum_nights                  96651 non-null  int64
#  11  number_of_reviews               96651 non-null  int64
#  12  last_review                     71487 non-null  object
#  13  reviews_per_month               71487 non-null  float64
#  14  calculated_host_listings_count  96651 non-null  int64
#  15  availability_365                96651 non-null  int64
#  16  number_of_reviews_ltm           96651 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(7), object(5)
# memory usage: 13.3+ MB

# %%
df_2 = pd.read_csv("/Users/brigitte/Desktop/Tesis Maestria/Thesis pipeline OG/LONDON/listings 2.csv", encoding="utf-8")

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96651 entries, 0 to 96650
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            96651 non-null  int64
#  1   listing_url                                   96651 non-null  object
#  2   scrape_id                                     96651 non-null  int64
#  3   last_scraped                                  96651 non-null  object
#  4   source                                        96651 non-null  object
#  5   name                                          96651 non-null  object
#  6   description                                   93806 non-null  object
#  7   neighborhood_overview                         41983 non-null  object
#  8   picture_url                                   96642 non-null  object
#  9   host_id                                       96651 non-null  int64
#  10  host_url                                      96651 non-null  object
#  11  host_name                                     96611 non-null  object
#  12  host_since                                    96613 non-null  object
#  13  host_location                                 73323 non-null  object
#  14  host_about                                    49314 non-null  object
#  15  host_response_time                            63627 non-null  object
#  16  host_response_rate                            63627 non-null  object
#  17  host_acceptance_rate                          69036 non-null  object
#  18  host_is_superhost                             94828 non-null  object
#  19  host_thumbnail_url                            96613 non-null  object
#  20  host_picture_url                              96613 non-null  object
#  21  host_neighbourhood                            46291 non-null  object
#  22  host_listings_count                           96613 non-null  float64
#  23  host_total_listings_count                     96613 non-null  float64
#  24  host_verifications                            96651 non-null  object
#  25  host_has_profile_pic                          96613 non-null  object
#  26  host_identity_verified                        96613 non-null  object
#  27  neighbourhood                                 41984 non-null  object
#  28  neighbourhood_cleansed                        96651 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      96651 non-null  float64
#  31  longitude                                     96651 non-null  float64
#  32  property_type                                 96651 non-null  object
#  33  room_type                                     96651 non-null  object
#  34  accommodates                                  96651 non-null  int64
#  35  bathrooms                                     62730 non-null  float64
#  36  bathrooms_text                                96502 non-null  object
#  37  bedrooms                                      84071 non-null  float64
#  38  beds                                          62676 non-null  float64
#  39  amenities                                     96651 non-null  object
#  40  price                                         62684 non-null  object
#  41  minimum_nights                                96651 non-null  int64
#  42  maximum_nights                                96651 non-null  int64
#  43  minimum_minimum_nights                        96651 non-null  int64
#  44  maximum_minimum_nights                        96651 non-null  int64
#  45  minimum_maximum_nights                        96651 non-null  int64
#  46  maximum_maximum_nights                        96651 non-null  int64
#  47  minimum_nights_avg_ntm                        96651 non-null  float64
#  48  maximum_nights_avg_ntm                        96651 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              92188 non-null  object
#  51  availability_30                               96651 non-null  int64
#  52  availability_60                               96651 non-null  int64
#  53  availability_90                               96651 non-null  int64
#  54  availability_365                              96651 non-null  int64
#  55  calendar_last_scraped                         96651 non-null  object
#  56  number_of_reviews                             96651 non-null  int64
#  57  number_of_reviews_ltm                         96651 non-null  int64
#  58  number_of_reviews_l30d                        96651 non-null  int64
#  59  availability_eoy                              96651 non-null  int64
#  60  number_of_reviews_ly                          96651 non-null  int64
#  61  estimated_occupancy_l365d                     96651 non-null  int64
#  62  estimated_revenue_l365d                       62684 non-null  float64
#  63  first_review                                  71487 non-null  object
#  64  last_review                                   71487 non-null  object
#  65  review_scores_rating                          71487 non-null  float64
#  66  review_scores_accuracy                        71472 non-null  float64
#  67  review_scores_cleanliness                     71478 non-null  float64
#  68  review_scores_checkin                         71443 non-null  float64
#  69  review_scores_communication                   71466 non-null  float64
#  70  review_scores_location                        71442 non-null  float64
#  71  review_scores_value                           71442 non-null  float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              96651 non-null  object
#  74  calculated_host_listings_count                96651 non-null  int64
#  75  calculated_host_listings_count_entire_homes   96651 non-null  int64
#  76  calculated_host_listings_count_private_rooms  96651 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   96651 non-null  int64
#  78  reviews_per_month                             71487 non-null  float64
# dtypes: float64(21), int64(24), object(34)
# memory usage: 58.3+ MB

# %%
df = df_1.merge(df_2, on="id", how="inner")

# %%
df.head()
# Out:
#        id                                           name_x  host_id_x  \
# 0  264776                      Huge Four Bedroom Apartment    1389063
# 1  264777                            One Bedroom Apartment    1389063
# 2  264778          Two Bedroom Newly Refurbished Apartment    1389063
# 3  264779                Refurbished Two Bedroom Apartment    1389063
# 4  264780  Spacious refurbished 2 bedroom apt with balcony    1389063
#
#   host_name_x  neighbourhood_group neighbourhood_x  latitude_x  longitude_x  \
# 0         Sue                  NaN        Lewisham    51.44306     -0.01948
# 1         Sue                  NaN        Lewisham    51.44284     -0.01997
# 2         Sue                  NaN        Lewisham    51.44359     -0.02275
# 3         Sue                  NaN        Lewisham    51.44355     -0.02309
# 4         Sue                  NaN        Lewisham    51.44333     -0.02307
#
#        room_type_x  price_x  minimum_nights_x  number_of_reviews_x  \
# 0  Entire home/apt    297.0                 3                   68
# 1  Entire home/apt     98.0                 3                   24
# 2  Entire home/apt    148.0                 3                   58
# 3  Entire home/apt    144.0                 3                   36
# 4  Entire home/apt    157.0                 3                   54
#
#   last_review_x  reviews_per_month_x  calculated_host_listings_count_x  \
# 0    2025-05-28                 0.51                                11
# 1    2024-12-11                 0.22                                11
# 2    2025-05-01                 0.43                                11
# 3    2025-04-10                 0.30                                11
# 4    2024-12-29                 0.35                                11
#
#    availability_365_x  number_of_reviews_ltm_x  license_x  \
# 0                 293                       12        NaN
# 1                 318                        4        NaN
# 2                 302                        6        NaN
# 3                 328                        7        NaN
# 4                 255                        4        NaN
#
#                            listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/264776  20250610032232   2025-06-11
# 1  https://www.airbnb.com/rooms/264777  20250610032232   2025-06-11
# 2  https://www.airbnb.com/rooms/264778  20250610032232   2025-06-11
# 3  https://www.airbnb.com/rooms/264779  20250610032232   2025-06-11
# 4  https://www.airbnb.com/rooms/264780  20250610032232   2025-06-11
#
#         source                                           name_y  \
# 0  city scrape                      Huge Four Bedroom Apartment
# 1  city scrape                            One Bedroom Apartment
# 2  city scrape          Two Bedroom Newly Refurbished Apartment
# 3  city scrape                Refurbished Two Bedroom Apartment
# 4  city scrape  Spacious refurbished 2 bedroom apt with balcony
#
#                                          description  \
# 0  An extremely large and sunny four bedroom grou...
# 1  Recently refurbished sunny one bedroom first f...
# 2  A large and sunny two bedroom second floor apa...
# 3  A large and sunny two bedroom second floor apa...
# 4  Completely refurbished 2 bedroom apt to sleep ...
#
#                                neighborhood_overview  \
# 0  Catford is a well established London suburb. T...
# 1                                                NaN
# 2  Catford is a well established London suburb. T...
# 3  Catford is a well established London suburb. T...
# 4                                                NaN
#
#                                          picture_url  host_id_y  \
# 0  https://a0.muscache.com/pictures/hosting/Hosti...    1389063
# 1  https://a0.muscache.com/pictures/hosting/Hosti...    1389063
# 2  https://a0.muscache.com/pictures/50662093/af12...    1389063
# 3  https://a0.muscache.com/pictures/50660860/e440...    1389063
# 4  https://a0.muscache.com/pictures/airflow/Hosti...    1389063
#
#                                     host_url host_name_y  host_since  \
# 0  https://www.airbnb.com/users/show/1389063         Sue  2011-11-09
# 1  https://www.airbnb.com/users/show/1389063         Sue  2011-11-09
# 2  https://www.airbnb.com/users/show/1389063         Sue  2011-11-09
# 3  https://www.airbnb.com/users/show/1389063         Sue  2011-11-09
# 4  https://www.airbnb.com/users/show/1389063         Sue  2011-11-09
#
#     host_location                                         host_about  \
# 0  United Kingdom  I own the Glenthurston Apartments and have don...
# 1  United Kingdom  I own the Glenthurston Apartments and have don...
# 2  United Kingdom  I own the Glenthurston Apartments and have don...
# 3  United Kingdom  I own the Glenthurston Apartments and have don...
# 4  United Kingdom  I own the Glenthurston Apartments and have don...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour                86%                 100%
# 1     within an hour                86%                 100%
# 2     within an hour                86%                 100%
# 3     within an hour                86%                 100%
# 4     within an hour                86%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 1                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 2                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 3                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 4                 f  https://a0.muscache.com/im/pictures/user/a0985...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 1  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 2  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 3  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 4  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                 11.0                       12.0  ['email', 'phone']
# 1                 11.0                       12.0  ['email', 'phone']
# 2                 11.0                       12.0  ['email', 'phone']
# 3                 11.0                       12.0  ['email', 'phone']
# 4                 11.0                       12.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified          neighbourhood_y  \
# 0                    t                      t  Neighborhood highlights
# 1                    t                      t                      NaN
# 2                    t                      t  Neighborhood highlights
# 3                    t                      t  Neighborhood highlights
# 4                    t                      t                      NaN
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude_y  \
# 0               Lewisham                           NaN    51.44306
# 1               Lewisham                           NaN    51.44284
# 2               Lewisham                           NaN    51.44359
# 3               Lewisham                           NaN    51.44355
# 4               Lewisham                           NaN    51.44333
#
#    longitude_y       property_type      room_type_y  accommodates  bathrooms  \
# 0     -0.01948  Entire rental unit  Entire home/apt            10        2.0
# 1     -0.01997  Entire rental unit  Entire home/apt             2        1.0
# 2     -0.02275  Entire rental unit  Entire home/apt             4        1.0
# 3     -0.02309  Entire rental unit  Entire home/apt             5        1.0
# 4     -0.02307  Entire rental unit  Entire home/apt             4        2.0
#
#   bathrooms_text  bedrooms  beds  \
# 0        2 baths       4.0   8.0
# 1         1 bath       1.0   2.0
# 2         1 bath       2.0   3.0
# 3         1 bath       2.0   5.0
# 4        2 baths       2.0   4.0
#
#                                            amenities  price_y  \
# 0  ["Cooking basics", "Washer", "Iron", "Smoke al...  $297.00
# 1  ["Cooking basics", "Wine glasses", "Iron", "Sm...   $98.00
# 2  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $148.00
# 3  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $144.00
# 4  ["Cooking basics", "Washer", "Iron", "Smoke al...  $157.00
#
#    minimum_nights_y  maximum_nights  minimum_minimum_nights  \
# 0                 3             365                       3
# 1                 3             365                       3
# 2                 3             365                       1
# 3                 3             365                       3
# 4                 3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                    1125                    1125
# 1                       3                    1125                    1125
# 2                       3                    1125                    1125
# 3                       3                    1125                    1125
# 4                       3                    1125                    1125
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.0                  1125.0               NaN
# 1                     3.0                  1125.0               NaN
# 2                     3.0                  1125.0               NaN
# 3                     3.0                  1125.0               NaN
# 4                     3.0                  1125.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               13               15               31
# 1                t                0               13               43
# 2                t                3                6               27
# 3                t               11               33               53
# 4                t                0                9               11
#
#    availability_365_y calendar_last_scraped  number_of_reviews_y  \
# 0                 293            2025-06-11                   68
# 1                 318            2025-06-11                   24
# 2                 302            2025-06-11                   58
# 3                 328            2025-06-11                   36
# 4                 255            2025-06-11                   54
#
#    number_of_reviews_ltm_y  number_of_reviews_l30d  availability_eoy  \
# 0                       12                       1               134
# 1                        4                       0               157
# 2                        6                       0               141
# 3                        7                       0               167
# 4                        4                       0               101
#
#    number_of_reviews_ly  estimated_occupancy_l365d  estimated_revenue_l365d  \
# 0                    15                        110                  32670.0
# 1                     7                         37                   3626.0
# 2                     8                         55                   8140.0
# 3                     7                         64                   9216.0
# 4                     7                         37                   5809.0
#
#   first_review last_review_y  review_scores_rating  review_scores_accuracy  \
# 0   2014-07-03    2025-05-28                  4.68                    4.65
# 1   2016-07-21    2024-12-11                  4.58                    4.42
# 2   2014-04-21    2025-05-01                  4.50                    4.50
# 3   2015-07-23    2025-04-10                  4.64                    4.67
# 4   2012-09-18    2024-12-29                  4.68                    4.78
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.72                   4.84
# 1                       4.54                   4.58
# 2                       4.45                   4.72
# 3                       4.58                   4.83
# 4                       4.65                   4.81
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.74                    4.62                 4.72
# 1                         4.25                    4.54                 4.42
# 2                         4.52                    4.36                 4.38
# 3                         4.61                    4.50                 4.47
# 4                         4.74                    4.37                 4.59
#
#    license_y instant_bookable  calculated_host_listings_count_y  \
# 0        NaN                t                                11
# 1        NaN                t                                11
# 2        NaN                t                                11
# 3        NaN                t                                11
# 4        NaN                t                                11
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           11
# 1                                           11
# 2                                           11
# 3                                           11
# 4                                           11
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month_y
# 0                                            0                 0.51
# 1                                            0                 0.22
# 2                                            0                 0.43
# 3                                            0                 0.30
# 4                                            0                 0.35

# %% [markdown]
# # 3. Data Cleaning

# %%
#Dropping duplicate columns

cols = df.columns
cols_x = [c for c in cols if c.endswith("_x")]
cols_y = [c for c in cols if c.endswith("_y")]

df = df.drop(columns= cols_x)

rename_dict = {col: col.replace("_y", "") for col in cols_y}
df = df.rename(columns=rename_dict)

# %%
#Dropping columns that all values are null 

df_1 = df.dropna(axis=1, how="all")
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96651 entries, 0 to 96650
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            96651 non-null  int64
#  1   listing_url                                   96651 non-null  object
#  2   scrape_id                                     96651 non-null  int64
#  3   last_scraped                                  96651 non-null  object
#  4   source                                        96651 non-null  object
#  5   name                                          96651 non-null  object
#  6   description                                   93806 non-null  object
#  7   neighborhood_overview                         41983 non-null  object
#  8   picture_url                                   96642 non-null  object
#  9   host_id                                       96651 non-null  int64
#  10  host_url                                      96651 non-null  object
#  11  host_name                                     96611 non-null  object
#  12  host_since                                    96613 non-null  object
#  13  host_location                                 73323 non-null  object
#  14  host_about                                    49314 non-null  object
#  15  host_response_time                            63627 non-null  object
#  16  host_response_rate                            63627 non-null  object
#  17  host_acceptance_rate                          69036 non-null  object
#  18  host_is_superhost                             94828 non-null  object
#  19  host_thumbnail_url                            96613 non-null  object
#  20  host_picture_url                              96613 non-null  object
#  21  host_neighbourhood                            46291 non-null  object
#  22  host_listings_count                           96613 non-null  float64
#  23  host_total_listings_count                     96613 non-null  float64
#  24  host_verifications                            96651 non-null  object
#  25  host_has_profile_pic                          96613 non-null  object
#  26  host_identity_verified                        96613 non-null  object
#  27  neighbourhood                                 41984 non-null  object
#  28  neighbourhood_cleansed                        96651 non-null  object
#  29  latitude                                      96651 non-null  float64
#  30  longitude                                     96651 non-null  float64
#  31  property_type                                 96651 non-null  object
#  32  room_type                                     96651 non-null  object
#  33  accommodates                                  96651 non-null  int64
#  34  bathrooms                                     62730 non-null  float64
#  35  bathrooms_text                                96502 non-null  object
#  36  bedrooms                                      84071 non-null  float64
#  37  beds                                          62676 non-null  float64
#  38  amenities                                     96651 non-null  object
#  39  price                                         62684 non-null  object
#  40  minimum_nights                                96651 non-null  int64
#  41  maximum_nights                                96651 non-null  int64
#  42  minimum_minimum_nights                        96651 non-null  int64
#  43  maximum_minimum_nights                        96651 non-null  int64
#  44  minimum_maximum_nights                        96651 non-null  int64
#  45  maximum_maximum_nights                        96651 non-null  int64
#  46  minimum_nights_avg_ntm                        96651 non-null  float64
#  47  maximum_nights_avg_ntm                        96651 non-null  float64
#  48  has_availability                              92188 non-null  object
#  49  availability_30                               96651 non-null  int64
#  50  availability_60                               96651 non-null  int64
#  51  availability_90                               96651 non-null  int64
#  52  availability_365                              96651 non-null  int64
#  53  calendar_last_scraped                         96651 non-null  object
#  54  number_of_reviews                             96651 non-null  int64
#  55  number_of_reviews_ltm                         96651 non-null  int64
#  56  number_of_reviews_l30d                        96651 non-null  int64
#  57  availability_eoy                              96651 non-null  int64
#  58  number_of_reviews_ly                          96651 non-null  int64
#  59  estimated_occupancy_l365d                     96651 non-null  int64
#  60  estimated_revenue_l365d                       62684 non-null  float64
#  61  first_review                                  71487 non-null  object
#  62  last_review                                   71487 non-null  object
#  63  review_scores_rating                          71487 non-null  float64
#  64  review_scores_accuracy                        71472 non-null  float64
#  65  review_scores_cleanliness                     71478 non-null  float64
#  66  review_scores_checkin                         71443 non-null  float64
#  67  review_scores_communication                   71466 non-null  float64
#  68  review_scores_location                        71442 non-null  float64
#  69  review_scores_value                           71442 non-null  float64
#  70  instant_bookable                              96651 non-null  object
#  71  calculated_host_listings_count                96651 non-null  int64
#  72  calculated_host_listings_count_entire_homes   96651 non-null  int64
#  73  calculated_host_listings_count_private_rooms  96651 non-null  int64
#  74  calculated_host_listings_count_shared_rooms   96651 non-null  int64
#  75  reviews_per_month                             71487 non-null  float64
# dtypes: float64(18), int64(24), object(34)
# memory usage: 56.8+ MB

# %%
df_1.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  264776  https://www.airbnb.com/rooms/264776  20250610032232   2025-06-11
# 1  264777  https://www.airbnb.com/rooms/264777  20250610032232   2025-06-11
# 2  264778  https://www.airbnb.com/rooms/264778  20250610032232   2025-06-11
# 3  264779  https://www.airbnb.com/rooms/264779  20250610032232   2025-06-11
# 4  264780  https://www.airbnb.com/rooms/264780  20250610032232   2025-06-11
#
#         source                                             name  \
# 0  city scrape                      Huge Four Bedroom Apartment
# 1  city scrape                            One Bedroom Apartment
# 2  city scrape          Two Bedroom Newly Refurbished Apartment
# 3  city scrape                Refurbished Two Bedroom Apartment
# 4  city scrape  Spacious refurbished 2 bedroom apt with balcony
#
#                                          description  \
# 0  An extremely large and sunny four bedroom grou...
# 1  Recently refurbished sunny one bedroom first f...
# 2  A large and sunny two bedroom second floor apa...
# 3  A large and sunny two bedroom second floor apa...
# 4  Completely refurbished 2 bedroom apt to sleep ...
#
#                                neighborhood_overview  \
# 0  Catford is a well established London suburb. T...
# 1                                                NaN
# 2  Catford is a well established London suburb. T...
# 3  Catford is a well established London suburb. T...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/hosting/Hosti...  1389063
# 1  https://a0.muscache.com/pictures/hosting/Hosti...  1389063
# 2  https://a0.muscache.com/pictures/50662093/af12...  1389063
# 3  https://a0.muscache.com/pictures/50660860/e440...  1389063
# 4  https://a0.muscache.com/pictures/airflow/Hosti...  1389063
#
#                                     host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 1  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 2  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 3  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 4  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
#
#     host_location                                         host_about  \
# 0  United Kingdom  I own the Glenthurston Apartments and have don...
# 1  United Kingdom  I own the Glenthurston Apartments and have don...
# 2  United Kingdom  I own the Glenthurston Apartments and have don...
# 3  United Kingdom  I own the Glenthurston Apartments and have don...
# 4  United Kingdom  I own the Glenthurston Apartments and have don...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour                86%                 100%
# 1     within an hour                86%                 100%
# 2     within an hour                86%                 100%
# 3     within an hour                86%                 100%
# 4     within an hour                86%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 1                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 2                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 3                 f  https://a0.muscache.com/im/pictures/user/a0985...
# 4                 f  https://a0.muscache.com/im/pictures/user/a0985...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 1  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 2  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 3  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
# 4  https://a0.muscache.com/im/pictures/user/a0985...         Bellingham
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                 11.0                       12.0  ['email', 'phone']
# 1                 11.0                       12.0  ['email', 'phone']
# 2                 11.0                       12.0  ['email', 'phone']
# 3                 11.0                       12.0  ['email', 'phone']
# 4                 11.0                       12.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified            neighbourhood  \
# 0                    t                      t  Neighborhood highlights
# 1                    t                      t                      NaN
# 2                    t                      t  Neighborhood highlights
# 3                    t                      t  Neighborhood highlights
# 4                    t                      t                      NaN
#
#   neighbourhood_cleansed  latitude  longitude       property_type  \
# 0               Lewisham  51.44306   -0.01948  Entire rental unit
# 1               Lewisham  51.44284   -0.01997  Entire rental unit
# 2               Lewisham  51.44359   -0.02275  Entire rental unit
# 3               Lewisham  51.44355   -0.02309  Entire rental unit
# 4               Lewisham  51.44333   -0.02307  Entire rental unit
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt            10        2.0        2 baths       4.0   8.0
# 1  Entire home/apt             2        1.0         1 bath       1.0   2.0
# 2  Entire home/apt             4        1.0         1 bath       2.0   3.0
# 3  Entire home/apt             5        1.0         1 bath       2.0   5.0
# 4  Entire home/apt             4        2.0        2 baths       2.0   4.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Cooking basics", "Washer", "Iron", "Smoke al...  $297.00               3
# 1  ["Cooking basics", "Wine glasses", "Iron", "Sm...   $98.00               3
# 2  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $148.00               3
# 3  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $144.00               3
# 4  ["Cooking basics", "Washer", "Iron", "Smoke al...  $157.00               3
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                       3                       3
# 1             365                       3                       3
# 2             365                       1                       3
# 3             365                       3                       3
# 4             365                       3                       3
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     3.0
# 1                    1125                    1125                     3.0
# 2                    1125                    1125                     3.0
# 3                    1125                    1125                     3.0
# 4                    1125                    1125                     3.0
#
#    maximum_nights_avg_ntm has_availability  availability_30  availability_60  \
# 0                  1125.0                t               13               15
# 1                  1125.0                t                0               13
# 2                  1125.0                t                3                6
# 3                  1125.0                t               11               33
# 4                  1125.0                t                0                9
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               31               293            2025-06-11                 68
# 1               43               318            2025-06-11                 24
# 2               27               302            2025-06-11                 58
# 3               53               328            2025-06-11                 36
# 4               11               255            2025-06-11                 54
#
#    number_of_reviews_ltm  number_of_reviews_l30d  availability_eoy  \
# 0                     12                       1               134
# 1                      4                       0               157
# 2                      6                       0               141
# 3                      7                       0               167
# 4                      4                       0               101
#
#    number_of_reviews_ly  estimated_occupancy_l365d  estimated_revenue_l365d  \
# 0                    15                        110                  32670.0
# 1                     7                         37                   3626.0
# 2                     8                         55                   8140.0
# 3                     7                         64                   9216.0
# 4                     7                         37                   5809.0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2014-07-03  2025-05-28                  4.68                    4.65
# 1   2016-07-21  2024-12-11                  4.58                    4.42
# 2   2014-04-21  2025-05-01                  4.50                    4.50
# 3   2015-07-23  2025-04-10                  4.64                    4.67
# 4   2012-09-18  2024-12-29                  4.68                    4.78
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.72                   4.84
# 1                       4.54                   4.58
# 2                       4.45                   4.72
# 3                       4.58                   4.83
# 4                       4.65                   4.81
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.74                    4.62                 4.72
# 1                         4.25                    4.54                 4.42
# 2                         4.52                    4.36                 4.38
# 3                         4.61                    4.50                 4.47
# 4                         4.74                    4.37                 4.59
#
#   instant_bookable  calculated_host_listings_count  \
# 0                t                              11
# 1                t                              11
# 2                t                              11
# 3                t                              11
# 4                t                              11
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           11
# 1                                           11
# 2                                           11
# 3                                           11
# 4                                           11
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.51
# 1                                            0               0.22
# 2                                            0               0.43
# 3                                            0               0.30
# 4                                            0               0.35

# %%
#1st Checking missing values

missing_info = df_1.isnull().sum().to_frame(name="Missing count")
missing_info["Missing %"] = (missing_info["Missing count"] / len(df_1)) * 100
missing_info = missing_info[missing_info["Missing count"] > 0].sort_values (by="Missing %", ascending=False)

print(missing_info)
# Out:
#                              Missing count  Missing %
# neighborhood_overview                54668  56.562270
# neighbourhood                        54667  56.561236
# host_neighbourhood                   50360  52.104996
# host_about                           47337  48.977248
# beds                                 33975  35.152249
# price                                33967  35.143972
# estimated_revenue_l365d              33967  35.143972
# bathrooms                            33921  35.096378
# host_response_rate                   33024  34.168296
# host_response_time                   33024  34.168296
# host_acceptance_rate                 27615  28.571872
# review_scores_location               25209  26.082503
# review_scores_value                  25209  26.082503
# review_scores_checkin                25208  26.081468
# review_scores_communication          25185  26.057671
# review_scores_accuracy               25179  26.051464
# review_scores_cleanliness            25173  26.045256
# review_scores_rating                 25164  26.035944
# last_review                          25164  26.035944
# first_review                         25164  26.035944
# reviews_per_month                    25164  26.035944
# host_location                        23328  24.136326
# bedrooms                             12580  13.015903
# has_availability                      4463   4.617645
# description                           2845   2.943581
# host_is_superhost                     1823   1.886168
# bathrooms_text                         149   0.154163
# host_name                               40   0.041386
# host_identity_verified                  38   0.039317
# host_has_profile_pic                    38   0.039317
# host_total_listings_count               38   0.039317
# host_listings_count                     38   0.039317
# host_picture_url                        38   0.039317
# host_thumbnail_url                      38   0.039317
# host_since                              38   0.039317
# picture_url                              9   0.009312

# %%
#Handling missing values: 1st section

#neighbourhood_overview and host_about features

df_1 = df_1.copy()
df_1["new_neighborhood_overview"] = df_1["neighborhood_overview"].notna().astype(int)
df_1["new_host_about"] = df_1["host_about"].notna().astype(int)

df_2 = df_1.drop(columns=["neighborhood_overview", "host_about"], axis=1)

#neighbourhood and host neighbourhood features

categorical_columns = [
    "neighbourhood", "host_neighbourhood",
]

for col in categorical_columns:
    df_2[col] = df_2[col].fillna("no information")

#price and beds features

df_3 = df_2.dropna(subset=["price", "beds"])

# %%
#2nd Checking missing values

missing_info = df_3.isnull().sum().to_frame(name="Missing count")
missing_info["Missing %"] = (missing_info["Missing count"] / len(df_3)) * 100
missing_info = missing_info[missing_info["Missing count"] > 0].sort_values (by="Missing %", ascending=False)

print(missing_info)
# Out:
#                              Missing count  Missing %
# host_location                        17366  27.750523
# review_scores_checkin                14932  23.861040
# review_scores_value                  14931  23.859442
# review_scores_location               14931  23.859442
# review_scores_communication          14930  23.857844
# review_scores_cleanliness            14930  23.857844
# review_scores_accuracy               14930  23.857844
# reviews_per_month                    14928  23.854648
# first_review                         14928  23.854648
# review_scores_rating                 14928  23.854648
# last_review                          14928  23.854648
# host_response_time                    7610  12.160629
# host_response_rate                    7610  12.160629
# host_acceptance_rate                  5234   8.363828
# description                           1698   2.713370
# host_is_superhost                     1372   2.192429
# has_availability                       849   1.356685
# bedrooms                               115   0.183768
# bathrooms_text                          92   0.147014
# bathrooms                               80   0.127838
# host_name                               28   0.044743
# host_has_profile_pic                    26   0.041547
# host_total_listings_count               26   0.041547
# host_listings_count                     26   0.041547
# host_picture_url                        26   0.041547
# host_thumbnail_url                      26   0.041547
# host_since                              26   0.041547
# host_identity_verified                  26   0.041547
# picture_url                              7   0.011186

# %%
#Handling missing values: 2nd section

#host_location feature

df_3 = df_3.copy()

categorical_columns = [
    "host_location"
]

for col in categorical_columns:
     df_3[col] = df_3[col].fillna("no information")

# Reviews score features

review_score_columns = [   
    "review_scores_value", "review_scores_location", "review_scores_checkin", "review_scores_communication",
    "review_scores_accuracy", "review_scores_cleanliness", "review_scores_rating", "reviews_per_month", "review_scores_rating"    
]

for col in review_score_columns:
    df_3[col] = df_3[col].fillna(0.0)

# First review feature

df_4 = df_3.drop(columns=["first_review", "last_review"], axis=1)

# %%
#3rd Checking missing values

missing_info = df_4.isnull().sum().to_frame(name="Missing count")
missing_info["Missing %"] = (missing_info["Missing count"] / len(df_4)) * 100
missing_info = missing_info[missing_info["Missing count"] > 0].sort_values (by="Missing %", ascending=False)

print(missing_info)
# Out:
#                            Missing count  Missing %
# host_response_rate                  7610  12.160629
# host_response_time                  7610  12.160629
# host_acceptance_rate                5234   8.363828
# description                         1698   2.713370
# host_is_superhost                   1372   2.192429
# has_availability                     849   1.356685
# bedrooms                             115   0.183768
# bathrooms_text                        92   0.147014
# bathrooms                             80   0.127838
# host_name                             28   0.044743
# host_since                            26   0.041547
# host_thumbnail_url                    26   0.041547
# host_listings_count                   26   0.041547
# host_total_listings_count             26   0.041547
# host_has_profile_pic                  26   0.041547
# host_identity_verified                26   0.041547
# host_picture_url                      26   0.041547
# picture_url                            7   0.011186

# %%
# Handling missing values: 3rd section

df_4 = df_4.copy()

# Host_response_rate and host_acceptance_rate features

percentage_columns = ["host_response_rate", "host_acceptance_rate"]

for col in percentage_columns:
    df_4[col] = df_4[col].fillna(0.0)

#host_response_time feature

categorical_columns = [
    "host_response_time"
]

for col in categorical_columns:
     df_4[col] = df_4[col].fillna("no information")

#description feature

df_4["new_description"] = df_4["description"].notna().astype(int)

df_5 = df_4.drop(columns=["description"], axis=1)

#host_is_superhost and has_availability features with true or false values (1 = True, 0 = False, 2 = No information)

df_5["host_is_superhost_label"] = df_5["host_is_superhost"].map({"t": 1, "f":0})
df_5["has_availability_label"] = df_5["has_availability"].map({"t": 1, "f":0})

df_5["host_is_superhost_label"] = df_5["host_is_superhost_label"].fillna("2")
df_5["has_availability_label"] = df_5[ "has_availability_label"].fillna("2")

#bedrooms, bathroom_text and bathrooms features
                                                                                                                             
df_6 = df_5.drop(columns=["bathrooms_text", "host_is_superhost", "has_availability"], axis=1)

bedrooms_columns = ["bedrooms", "bathrooms"]

for col in bedrooms_columns:
    df_6[col] = df_6[col].fillna(0.0)

# %%
#4th Checking missing values

missing_info = df_6.isnull().sum().to_frame(name="Missing count")
missing_info["Missing %"] = (missing_info["Missing count"] / len(df_6)) * 100
missing_info = missing_info[missing_info["Missing count"] > 0].sort_values (by="Missing %", ascending=False)

print(missing_info)
# Out:
#                            Missing count  Missing %
# host_name                             28   0.044743
# host_since                            26   0.041547
# host_thumbnail_url                    26   0.041547
# host_picture_url                      26   0.041547
# host_listings_count                   26   0.041547
# host_total_listings_count             26   0.041547
# host_has_profile_pic                  26   0.041547
# host_identity_verified                26   0.041547
# picture_url                            7   0.011186

# %%
# Handling missing values: 4th section

#host_name feature (unique identifier)

df_7 = df_6.drop(columns=["host_thumbnail_url", "host_picture_url", "picture_url"], axis=1)

#host_response_time feature

host_categorical_columns = ["host_name", "host_since", "host_has_profile_pic", "host_identity_verified"]

for col in host_categorical_columns:
     df_7[col] = df_7[col].fillna("no information")

#Host_listing_count features

host_numerical_columns = ["host_listings_count", "host_total_listings_count"]

for col in host_numerical_columns:
     df_7[col] = df_7[col].fillna("0.0")

# %%
#5th Checking missing values

missing_info = df_7.isnull().sum().to_frame(name="Missing count")
missing_info["Missing %"] = (missing_info["Missing count"] / len(df_7)) * 100
missing_info = missing_info[missing_info["Missing count"] > 0].sort_values (by="Missing %", ascending=False)

print(missing_info)
# Out:
# Empty DataFrame
# Columns: [Missing count, Missing %]
# Index: []

# %%
df_cleaned = df_7.copy()

# %% [markdown]
# # 4. Data Preprocessing

# %%
df_cleaned.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  264776  https://www.airbnb.com/rooms/264776  20250610032232   2025-06-11
# 1  264777  https://www.airbnb.com/rooms/264777  20250610032232   2025-06-11
# 2  264778  https://www.airbnb.com/rooms/264778  20250610032232   2025-06-11
# 3  264779  https://www.airbnb.com/rooms/264779  20250610032232   2025-06-11
# 4  264780  https://www.airbnb.com/rooms/264780  20250610032232   2025-06-11
#
#         source                                             name  host_id  \
# 0  city scrape                      Huge Four Bedroom Apartment  1389063
# 1  city scrape                            One Bedroom Apartment  1389063
# 2  city scrape          Two Bedroom Newly Refurbished Apartment  1389063
# 3  city scrape                Refurbished Two Bedroom Apartment  1389063
# 4  city scrape  Spacious refurbished 2 bedroom apt with balcony  1389063
#
#                                     host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 1  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 2  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 3  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
# 4  https://www.airbnb.com/users/show/1389063       Sue  2011-11-09
#
#     host_location host_response_time host_response_rate host_acceptance_rate  \
# 0  United Kingdom     within an hour                86%                 100%
# 1  United Kingdom     within an hour                86%                 100%
# 2  United Kingdom     within an hour                86%                 100%
# 3  United Kingdom     within an hour                86%                 100%
# 4  United Kingdom     within an hour                86%                 100%
#
#   host_neighbourhood host_listings_count host_total_listings_count  \
# 0         Bellingham                11.0                      12.0
# 1         Bellingham                11.0                      12.0
# 2         Bellingham                11.0                      12.0
# 3         Bellingham                11.0                      12.0
# 4         Bellingham                11.0                      12.0
#
#    host_verifications host_has_profile_pic host_identity_verified  \
# 0  ['email', 'phone']                    t                      t
# 1  ['email', 'phone']                    t                      t
# 2  ['email', 'phone']                    t                      t
# 3  ['email', 'phone']                    t                      t
# 4  ['email', 'phone']                    t                      t
#
#              neighbourhood neighbourhood_cleansed  latitude  longitude  \
# 0  Neighborhood highlights               Lewisham  51.44306   -0.01948
# 1           no information               Lewisham  51.44284   -0.01997
# 2  Neighborhood highlights               Lewisham  51.44359   -0.02275
# 3  Neighborhood highlights               Lewisham  51.44355   -0.02309
# 4           no information               Lewisham  51.44333   -0.02307
#
#         property_type        room_type  accommodates  bathrooms  bedrooms  \
# 0  Entire rental unit  Entire home/apt            10        2.0       4.0
# 1  Entire rental unit  Entire home/apt             2        1.0       1.0
# 2  Entire rental unit  Entire home/apt             4        1.0       2.0
# 3  Entire rental unit  Entire home/apt             5        1.0       2.0
# 4  Entire rental unit  Entire home/apt             4        2.0       2.0
#
#    beds                                          amenities    price  \
# 0   8.0  ["Cooking basics", "Washer", "Iron", "Smoke al...  $297.00
# 1   2.0  ["Cooking basics", "Wine glasses", "Iron", "Sm...   $98.00
# 2   3.0  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $148.00
# 3   5.0  ["Cooking basics", "Iron", "Smoke alarm", "Fir...  $144.00
# 4   4.0  ["Cooking basics", "Washer", "Iron", "Smoke al...  $157.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3             365                       3
# 1               3             365                       3
# 2               3             365                       1
# 3               3             365                       3
# 4               3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                    1125                    1125
# 1                       3                    1125                    1125
# 2                       3                    1125                    1125
# 3                       3                    1125                    1125
# 4                       3                    1125                    1125
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# 0                     3.0                  1125.0               13
# 1                     3.0                  1125.0                0
# 2                     3.0                  1125.0                3
# 3                     3.0                  1125.0               11
# 4                     3.0                  1125.0                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               15               31               293            2025-06-11
# 1               13               43               318            2025-06-11
# 2                6               27               302            2025-06-11
# 3               33               53               328            2025-06-11
# 4                9               11               255            2025-06-11
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 68                     12                       1
# 1                 24                      4                       0
# 2                 58                      6                       0
# 3                 36                      7                       0
# 4                 54                      4                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0               134                    15                        110
# 1               157                     7                         37
# 2               141                     8                         55
# 3               167                     7                         64
# 4               101                     7                         37
#
#    estimated_revenue_l365d  review_scores_rating  review_scores_accuracy  \
# 0                  32670.0                  4.68                    4.65
# 1                   3626.0                  4.58                    4.42
# 2                   8140.0                  4.50                    4.50
# 3                   9216.0                  4.64                    4.67
# 4                   5809.0                  4.68                    4.78
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.72                   4.84
# 1                       4.54                   4.58
# 2                       4.45                   4.72
# 3                       4.58                   4.83
# 4                       4.65                   4.81
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.74                    4.62                 4.72
# 1                         4.25                    4.54                 4.42
# 2                         4.52                    4.36                 4.38
# 3                         4.61                    4.50                 4.47
# 4                         4.74                    4.37                 4.59
#
#   instant_bookable  calculated_host_listings_count  \
# 0                t                              11
# 1                t                              11
# 2                t                              11
# 3                t                              11
# 4                t                              11
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           11
# 1                                           11
# 2                                           11
# 3                                           11
# 4                                           11
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               0.51
# 1                                            0               0.22
# 2                                            0               0.43
# 3                                            0               0.30
# 4                                            0               0.35
#
#    new_neighborhood_overview  new_host_about  new_description  \
# 0                          1               1                1
# 1                          0               1                1
# 2                          1               1                1
# 3                          1               1                1
# 4                          0               1                1
#
#   host_is_superhost_label has_availability_label
# 0                     0.0                    1.0
# 1                     0.0                    1.0
# 2                     0.0                    1.0
# 3                     0.0                    1.0
# 4                     0.0                    1.0

# %%
# 1st Feature engineering section 

#dropping features with unique identifiers and non relevant information

df_8 = df_cleaned.drop(columns=["id", "listing_url", "scrape_id", "source", "name", "host_id", "host_url", "host_name", "neighbourhood",
                               "last_scraped", "calendar_last_scraped"])

#host_since: extracting the amount of time that a host is in the platform

df_8["host_since"] = pd.to_datetime(df_8["host_since"], errors="coerce")
df_8["host_tenure_days"] = (datetime.now() - df_8["host_since"]).dt.days

#host_location: as the information is disperse it will be extracted if the host is from UK (Airbnb location) or not 
# 1 = Host is in UK; 0 = Host is not in the UK; -1 = Host location info is missing 

df_8["host_is_local"] = df_8["host_location"].apply(
    lambda x: 1 if isinstance(x,str) and "United Kingdom" in x else(0 if isinstance(x,str) else -1)
)

df_9 = df_8.drop(columns=["host_location", "host_since"])

# %%
# 2nd Feature engineering section

#Price feature - creating price per guest

df_9["price"] = df_9["price"].replace("[\$,]", "", regex=True).astype(float)

df_9["price_per_guest"] = df_9.apply(
    lambda row: round(row["price"] / row["accommodates"], 2) if row ["accommodates"] 
    and row["accommodates"]> 0 else round(row['price'], 2), axis=1
)

#Minimum_nights - creating bins to categorize 

def categorize_min_nights(n):
    if n<= 3:
        return "short_stay"
    elif n<=14:
        return "mid_stay"
    else:
        return "long_stay"
    
df_9["min_nights_category"] = df_9["minimum_nights"].apply(categorize_min_nights)

#dropping engineered features:

df_10 = df_9.drop(columns=["minimum_nights"])

# %%
# 3rd Feature engineering section

#Amenities, creating a column whether if the Airbnb listing have or do not have amenities and how many 

import ast

df_10["amenities_list"] = df_10["amenities"].apply(ast.literal_eval)

df_10["amenities_count"] = df_10["amenities_list"].apply(len)
    
#Maximum_nights, adjusting all the nights to maximum a year

max_night_cap = 365

df_10["maximum_nights_capped"] = df_10["maximum_nights"].apply(lambda x: min(x, max_night_cap))
    
#dropping features non needed

df_11 = df_10.drop(columns=["amenities", "amenities_list", "maximum_nights"])

# %%
# 4th Feature engineering section

#in this section some columns that contain redundant information will be dropped

df_12 = df_11.drop(columns=["minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights",
                                  "maximum_maximum_nights", "availability_60", "availability_90"])

# %%
# 5th Feature engineering section

#Creating bins for feature: reviews per month

bins = [0, 1, 5, 10, df_12["reviews_per_month"].max()]
labels = ["0-1", "2-5", "6-10", "11+"]

df_12["reviews_per_month_bins"] = pd.cut(df_12["reviews_per_month"], bins=bins, labels=labels, include_lowest=True)

# %%
df_12.head()
# Out:
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour                86%                 100%
# 1     within an hour                86%                 100%
# 2     within an hour                86%                 100%
# 3     within an hour                86%                 100%
# 4     within an hour                86%                 100%
#
#   host_neighbourhood host_listings_count host_total_listings_count  \
# 0         Bellingham                11.0                      12.0
# 1         Bellingham                11.0                      12.0
# 2         Bellingham                11.0                      12.0
# 3         Bellingham                11.0                      12.0
# 4         Bellingham                11.0                      12.0
#
#    host_verifications host_has_profile_pic host_identity_verified  \
# 0  ['email', 'phone']                    t                      t
# 1  ['email', 'phone']                    t                      t
# 2  ['email', 'phone']                    t                      t
# 3  ['email', 'phone']                    t                      t
# 4  ['email', 'phone']                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude       property_type  \
# 0               Lewisham  51.44306   -0.01948  Entire rental unit
# 1               Lewisham  51.44284   -0.01997  Entire rental unit
# 2               Lewisham  51.44359   -0.02275  Entire rental unit
# 3               Lewisham  51.44355   -0.02309  Entire rental unit
# 4               Lewisham  51.44333   -0.02307  Entire rental unit
#
#          room_type  accommodates  bathrooms  bedrooms  beds  price  \
# 0  Entire home/apt            10        2.0       4.0   8.0  297.0
# 1  Entire home/apt             2        1.0       1.0   2.0   98.0
# 2  Entire home/apt             4        1.0       2.0   3.0  148.0
# 3  Entire home/apt             5        1.0       2.0   5.0  144.0
# 4  Entire home/apt             4        2.0       2.0   4.0  157.0
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# 0                     3.0                  1125.0               13
# 1                     3.0                  1125.0                0
# 2                     3.0                  1125.0                3
# 3                     3.0                  1125.0               11
# 4                     3.0                  1125.0                0
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0               293                 68                     12
# 1               318                 24                      4
# 2               302                 58                      6
# 3               328                 36                      7
# 4               255                 54                      4
#
#    number_of_reviews_l30d  availability_eoy  number_of_reviews_ly  \
# 0                       1               134                    15
# 1                       0               157                     7
# 2                       0               141                     8
# 3                       0               167                     7
# 4                       0               101                     7
#
#    estimated_occupancy_l365d  estimated_revenue_l365d  review_scores_rating  \
# 0                        110                  32670.0                  4.68
# 1                         37                   3626.0                  4.58
# 2                         55                   8140.0                  4.50
# 3                         64                   9216.0                  4.64
# 4                         37                   5809.0                  4.68
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.65                       4.72                   4.84
# 1                    4.42                       4.54                   4.58
# 2                    4.50                       4.45                   4.72
# 3                    4.67                       4.58                   4.83
# 4                    4.78                       4.65                   4.81
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.74                    4.62                 4.72
# 1                         4.25                    4.54                 4.42
# 2                         4.52                    4.36                 4.38
# 3                         4.61                    4.50                 4.47
# 4                         4.74                    4.37                 4.59
#
#   instant_bookable  calculated_host_listings_count  \
# 0                t                              11
# 1                t                              11
# 2                t                              11
# 3                t                              11
# 4                t                              11
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           11
# 1                                           11
# 2                                           11
# 3                                           11
# 4                                           11
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               0.51
# 1                                            0               0.22
# 2                                            0               0.43
# 3                                            0               0.30
# 4                                            0               0.35
#
#    new_neighborhood_overview  new_host_about  new_description  \
# 0                          1               1                1
# 1                          0               1                1
# 2                          1               1                1
# 3                          1               1                1
# 4                          0               1                1
#
#   host_is_superhost_label has_availability_label  host_tenure_days  \
# 0                     0.0                    1.0            5055.0
# 1                     0.0                    1.0            5055.0
# 2                     0.0                    1.0            5055.0
# 3                     0.0                    1.0            5055.0
# 4                     0.0                    1.0            5055.0
#
#    host_is_local  price_per_guest min_nights_category  amenities_count  \
# 0              1            29.70          short_stay               35
# 1              1            49.00          short_stay               44
# 2              1            37.00          short_stay               27
# 3              1            28.80          short_stay               29
# 4              1            39.25          short_stay               35
#
#    maximum_nights_capped reviews_per_month_bins
# 0                    365                    0-1
# 1                    365                    0-1
# 2                    365                    0-1
# 3                    365                    0-1
# 4                    365                    0-1

# %%
df_final = df_12.copy()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62579 entries, 0 to 96650
# Data columns (total 55 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            62579 non-null  object
#  1   host_response_rate                            62579 non-null  object
#  2   host_acceptance_rate                          62579 non-null  object
#  3   host_neighbourhood                            62579 non-null  object
#  4   host_listings_count                           62579 non-null  object
#  5   host_total_listings_count                     62579 non-null  object
#  6   host_verifications                            62579 non-null  object
#  7   host_has_profile_pic                          62579 non-null  object
#  8   host_identity_verified                        62579 non-null  object
#  9   neighbourhood_cleansed                        62579 non-null  object
#  10  latitude                                      62579 non-null  float64
#  11  longitude                                     62579 non-null  float64
#  12  property_type                                 62579 non-null  object
#  13  room_type                                     62579 non-null  object
#  14  accommodates                                  62579 non-null  int64
#  15  bathrooms                                     62579 non-null  float64
#  16  bedrooms                                      62579 non-null  float64
#  17  beds                                          62579 non-null  float64
#  18  price                                         62579 non-null  float64
#  19  minimum_nights_avg_ntm                        62579 non-null  float64
#  20  maximum_nights_avg_ntm                        62579 non-null  float64
#  21  availability_30                               62579 non-null  int64
#  22  availability_365                              62579 non-null  int64
#  23  number_of_reviews                             62579 non-null  int64
#  24  number_of_reviews_ltm                         62579 non-null  int64
#  25  number_of_reviews_l30d                        62579 non-null  int64
#  26  availability_eoy                              62579 non-null  int64
#  27  number_of_reviews_ly                          62579 non-null  int64
#  28  estimated_occupancy_l365d                     62579 non-null  int64
#  29  estimated_revenue_l365d                       62579 non-null  float64
#  30  review_scores_rating                          62579 non-null  float64
#  31  review_scores_accuracy                        62579 non-null  float64
#  32  review_scores_cleanliness                     62579 non-null  float64
#  33  review_scores_checkin                         62579 non-null  float64
#  34  review_scores_communication                   62579 non-null  float64
#  35  review_scores_location                        62579 non-null  float64
#  36  review_scores_value                           62579 non-null  float64
#  37  instant_bookable                              62579 non-null  object
#  38  calculated_host_listings_count                62579 non-null  int64
#  39  calculated_host_listings_count_entire_homes   62579 non-null  int64
#  40  calculated_host_listings_count_private_rooms  62579 non-null  int64
#  41  calculated_host_listings_count_shared_rooms   62579 non-null  int64
#  42  reviews_per_month                             62579 non-null  float64
#  43  new_neighborhood_overview                     62579 non-null  int64
#  44  new_host_about                                62579 non-null  int64
#  45  new_description                               62579 non-null  int64
#  46  host_is_superhost_label                       62579 non-null  object
#  47  has_availability_label                        62579 non-null  object
#  48  host_tenure_days                              62553 non-null  float64
#  49  host_is_local                                 62579 non-null  int64
#  50  price_per_guest                               62579 non-null  float64
#  51  min_nights_category                           62579 non-null  object
#  52  amenities_count                               62579 non-null  int64
#  53  maximum_nights_capped                         62579 non-null  int64
#  54  reviews_per_month_bins                        62579 non-null  category
# dtypes: category(1), float64(19), int64(19), object(16)
# memory usage: 26.3+ MB

# %% [markdown]
# # 5. Data Visualization

# %% [markdown]
# # a. Host Characteristics

# %%
import plotly.io as pio
pio.renderers.default = "iframe_connected"

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
import plotly.graph_objects as go

#Mapping t/f to Yes/No for interpretation

df_sample = df_final.sample(20859, random_state=42)

df_sample["instant_bookable"] = df_sample["instant_bookable"].map({"t":"Yes", "f":"No"})

host_features = [("instant_bookable", "Instant Bookable Distribution")]

color_map = ["#FFA69E", "#FF5A5F"]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4,
                    marker=dict(colors=color_map))]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_118.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Mapping t/f to Yes/No for interpretation

df_sample["new_host_about"] = df_sample["new_host_about"].map({1:"Yes", 0:"No"})

host_features = [("new_host_about", "Host Description Distribution")]

color_map = ["#FFA69E", "#FF5A5F"]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4,
                    marker=dict(colors=color_map))]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
    del fig
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_120.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Mapping t/f to Yes/No for interpretation

df_sample["host_is_local"] = df_sample["host_is_local"].map({1:"Yes", 0:"No"})

host_features = [("host_is_local", "Local Hosts Distribution")]

color_map = ["#FFA69E", "#FF5A5F"]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4,
                    marker=dict(colors=color_map))]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
    del fig
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_122.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Mapping t/f to Yes/No for interpretation

df_sample["host_is_superhost_label"] = df_sample["host_is_superhost_label"].map({1.0:"Yes", 0.0:"No", "2":"No information"})

#Features and titles 

host_features = [("host_is_superhost_label", "Superhost Distribution")]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4)]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
    del fig
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_124.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Mapping t/f to Yes/No for interpretation

df_sample["host_has_profile_pic"] = df_sample["host_has_profile_pic"].map({"t":"Yes", "f":"No", "no information":"No information"})

#Features and titles 

host_features = [("host_has_profile_pic", "Host has Profile Picture")]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4)]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
    del fig
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_126.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Mapping t/f to Yes/No for interpretation

df_sample["host_identity_verified"] = df_sample["host_identity_verified"].map({"t":"Yes", "f":"No", "no information":"No information"})

#Features and titles 

host_features = [("host_identity_verified", "Host Identity Verified")]

for feature, title in host_features:
    counts = df_sample[feature].value_counts()
    labels = counts.index.tolist()
    values = counts.values.tolist()

    fig = go.Figure(
        data=[go.Pie(labels=labels, values=values, hole=0.4)]
    )

    fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
    fig.update_layout(title_text=title, title_font_size=20, width=600, height=600)
    fig.show()
    del fig
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_128.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_sample = df_final.sample(5000, random_state=42)

mappings = {
    "instant_bookable": {"t":"Yes", "f":"No"},
    "new_host_about": {1:"Yes", 0:"No"},
    "host_is_local": {1:"Yes", 0:"No"},
    "host_is_superhost_label": {1.0:"Yes", 0.0:"No", "2":"No information"},
    "host_has_profile_pic": {"t":"Yes", "f":"No", "no information":"No information"},
    "host_identity_verified": {"t":"Yes", "f":"No", "no information":"No information"}
}

for col, map_dict in mappings.items():
    df_sample[col] = df_sample[col].map(map_dict)

path_cols = [
    "host_is_superhost_label",
    "instant_bookable",
    "new_host_about",
    "host_is_local",
    "host_has_profile_pic",
    "host_identity_verified"
]

color_map_superhost = {
    "Yes": "#FF5A5F",
    "No": "rgba(0,0,0,0.05)", 
    "No information": "#FFD1D0"
}

fig = px.sunburst(
    df_sample,
    path=path_cols,
    color="host_is_superhost_label",
    color_discrete_map=color_map_superhost,
    title="Airbnb Host Characteristics Overview"
)

#legend for each ring
feature_labels = [
    "Ring 1: Superhost",
    "Ring 2: Instant Bookable",
    "Ring 3: Host Description",
    "Ring 4: Local Host",
    "Ring 5: Profile Picture",
    "Ring 6: Identity Verified"
]

for i, label in enumerate(feature_labels):
    fig.add_annotation(
        x=1.2, y=1-(i*0.1), xref="paper", yref="paper",
        text=label,
        showarrow=False,
        font=dict(size=12)
    )

fig.update_layout(
    width=900,
    height=900,
    margin=dict(t=50, l=0, r=150, b=0) 
)

fig.show(renderer="iframe_connected")
# Out:
# <iframe
#     scrolling="no"
#     width="920px"
#     height="920"
#     src="iframe_figures/figure_132.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.express as px

df_final["host_total_listings_count"] = pd.to_numeric(df_final["host_total_listings_count"], errors="coerce")

top_neighborhoods = (
    df_final.groupby("host_neighbourhood")["host_total_listings_count"].sum()
    .sort_values(ascending=False)
    .head()
    .reset_index()
)

fig = px.bar(
    top_neighborhoods,
    x="host_neighbourhood",
    y="host_total_listings_count",
    title="Top Neighborhoods by total listings",
    text="host_total_listings_count",
    color="host_total_listings_count",
    color_continuous_scale="Reds"
)

fig.update_layout(
    xaxis_title="Neighborhood", 
    yaxis_title="Total Listings", 
    width=1100,
    height=600,
    showlegend=True,
    coloraxis_colorbar=dict(title="Total Listings")
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1120px"
#     height="620"
#     src="iframe_figures/figure_90.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.express as px

df_final["host_total_listings_count"] = pd.to_numeric(df_final["host_total_listings_count"], errors="coerce")

top_neighborhoods = (
    df_final.groupby("host_neighbourhood")["host_total_listings_count"].mean()
    .sort_values(ascending=False)
    .head()
    .reset_index()
)

fig = px.bar(
    top_neighborhoods,
    x="host_neighbourhood",
    y="host_total_listings_count",
    title="Average Number of Listings per Host by Neighborhood",
    text="host_total_listings_count",
    color="host_total_listings_count",
    color_continuous_scale="Reds"
)

fig.update_layout(
    xaxis_title="Neighborhood", 
    yaxis_title="Total Listings", 
    width=1100,
    height=600,
    showlegend=True,
    coloraxis_colorbar=dict(title="Total Listings per Host")
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1120px"
#     height="620"
#     src="iframe_figures/figure_96.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Host Response time donut

response_counts = df_sample['host_response_time'].value_counts()
labels = response_counts.index.tolist()
values = response_counts.values.tolist()

color_map = ["#FF5A5F", "#FFA69E", "#FFD1D0", "rgba(0,0,0,0.05)"] 

fig = go.Figure(
    data=[go.Pie(labels=labels, values=values, hole=0.4, marker=dict(colors=color_map))]
)

fig.update_traces(textinfo="percent+label", hoverinfo="label+percent+value")
fig.update_layout(
    title="Host Response Time Distribution",
    title_font_size=20,
    width=800,
    height=800
)

fig.show(renderer="iframe_connected")
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_47.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_donut = df_sample.groupby(['host_is_superhost_label', 'host_response_time']).size().reset_index(name='count')

#sunburst
fig = px.sunburst(
    df_donut,
    path=['host_is_superhost_label', 'host_response_time'],
    values='count',
    color='host_is_superhost_label',
    color_discrete_map={
        "Yes": "#FF5A5F", 
        "No": "rgba(0,0,0,0.2)", 
        "No information": "#FFD1D0"
    },
    title="Host Response Time Distribution by Superhost Status",
)


fig.update_layout(
    width=700,
    height=700,
    margin=dict(t=50, l=0, r=0, b=0),
    legend_title_text="Superhost Status"
)

feature_labels = [
    "Ring 1: Superhost",
    "Ring 2: Response time"
]

for i, label in enumerate(feature_labels):
    fig.add_annotation(
        x=1.2, y=1-(i*0.1), xref="paper", yref="paper",
        text=label,
        showarrow=False,
        font=dict(size=12)
    )

fig.show(renderer="iframe_connected")
# Out:
# <iframe
#     scrolling="no"
#     width="720px"
#     height="720"
#     src="iframe_figures/figure_130.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
